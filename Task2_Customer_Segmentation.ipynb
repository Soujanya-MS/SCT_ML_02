# %% [markdown]
# **SkillCraft Technology Internship**
#
# **Task 02 — Customer Segmentation Using K-Means Clustering**
#
# **Intern Name: Soujanya M**
#
# **Objective**
#
# Create a **K-Means Clustering model** to group mall customers based on their:
#
# Annual Income (k$)
# Spending Score (1–100)
#
# This helps the retail store understand different customer types and plan better marketing strategies.
#
# **Dataset:Mall Customers Dataset**
#
# **Methods Used**
#
# * Loaded and inspected the dataset
# * Selected two key features: Annual Income and Spending Score
# * Applied the Elbow Method to determine the optimal number of clusters
# * Trained a K-Means model with 5 clusters
# * Visualized customer segments using a scatter plot
#
# **Results**
#
# **Optimal Number of Clusters: 5**
#
# (Identified using the Elbow Method)
#
# **Customer Groups Formed:**
#
# The K-Means model created five different customer segments:
#
# 1. Low income, low spending
# 2. Low income, high spending
# 3. Average income, average spending
# 4. High income, low spending
# 5. High income, high spending
#
# These groups help businesses plan targeted marketing and personalized offers.
#
#
# **Insights**
#
# * Customers with high income and high spending are ideal for premium marketing campaigns.
# * Customers with low income and low spending may respond better to discounts and budget offers.
# * The model shows clear separation between customer types, making segmentation useful.
# * Including additional features like Age, Gender, and purchase history could improve understanding.
#
# **Future Improvements**
#
# To make the segmentation more accurate, we could:
#
# * Add more features (Age, Gender, Annual Spending)
# * Use 3D clustering (with Age included)
# * Try other unsupervised learning methods like Hierarchical Clustering
# * Perform data scaling for better centroid placement
#
# **Conclusion**
#
# The K-Means model successfully grouped mall customers into five meaningful segments using income and spending patterns.
# This clustering helps the retail store understand behavior differences and plan smarter marketing strategies.

# %% [markdown]
# **Step 1 : Import basic python libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# **Step 2 : Load the dataset**

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# **Step 3 : Select the features**

# %%
X = df[["Annual Income (k$)", "Spending Score (1-100)"]]

# %% [markdown]
# **Step 4 : Use the Elbow Method to find the number of clusters and plot the Elbow Graph**

# %%
import warnings
warnings.filterwarnings("ignore")

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Move this OUTSIDE the loop
plt.plot(range(1, 11), wcss)
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

# %% [markdown]
# **Step 5: Apply K-Means with K = 5 (commonly best for this dataset)**

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
clusters = kmeans.fit_predict(X)
df["Cluster"] = clusters

# %% [markdown]
# **Step 6 : Visualize the clusters**

# %%
plt.figure(figsize=(8,5))

plt.scatter(X.iloc[:,0], X.iloc[:,1], c=clusters, s=50)
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("Customer Segments Using K-Means")
plt.show()

# %% [markdown]
# **Step 7 : Print final grouped data**

# %%
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4
